# %% [markdown]
# # 다문화가족 데이터(서울열린데이터광장, 서울특별시)

# %%
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기 
culture = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\다문화가정+학생+현황_20230118152535.csv",index_col = 0)
culture
# Out:
#          자치구별(2)   2021  2021.1 2021.2 2021.3  2021.4 2021.5 2021.6  2021.7  \
# 자치구별(1)
# 자치구별(1)  자치구별(2)   초등학교    초등학교   초등학교    중학교     중학교    중학교   고등학교    고등학교
# 자치구별(1)  자치구별(2)      계  국제결혼가정  외국인가정      계  국제결혼가정  외국인가정      계  국제결혼가정
# 서울시           소계  13093    8932   4161   4049    2839   1210   2053    1478
# 서울시          종로구    157     115     42     72      55     17     75      57
# 서울시           중구    245     151     94     78      53     25    104      77
# 서울시          용산구    402     255    147    133      87     46     86      62
# 서울시          성동구    449     333    116    130     100     30     42      33
# 서울시          광진구    503     295    208    132      92     40     69      51
# 서울시         동대문구    496     357    139    160     117     43     88      65
# 서울시          중랑구    592     431    161    176     139     37     49      39
# 서울시          성북구    564     458    106    177     145     32     63      54
# ...

# %%
culture = culture[['자치구별(2)','2021.6','2021.7','2021.8']]
culture
# Out:
#          자치구별(2) 2021.6  2021.7 2021.8
# 자치구별(1)
# 자치구별(1)  자치구별(2)   고등학교    고등학교   고등학교
# 자치구별(1)  자치구별(2)      계  국제결혼가정  외국인가정
# 서울시           소계   2053    1478    575
# 서울시          종로구     75      57     18
# 서울시           중구    104      77     27
# 서울시          용산구     86      62     24
# 서울시          성동구     42      33      9
# 서울시          광진구     69      51     18
# 서울시         동대문구     88      65     23
# 서울시          중랑구     49      39     10
# 서울시          성북구     63      54      9
# 서울시          강북구     68      61      7
# 서울시          도봉구     36      24     12
# 서울시          노원구     89      68     21
# 서울시          은평구    168     106     62
# 서울시         서대문구     40      31      9
# 서울시          마포구     54      40     14
# 서울시          양천구     77      67     10
# 서울시          강서구    101      89     12
# 서울시          구로구    228     132     96
# 서울시          금천구    100      59     41
# 서울시         영등포구     97      51     46
# 서울시          동작구     57      47     10
# ...

# %%
# 인덱스 수정 
culture.reset_index(drop=False, inplace=True)
culture
# Out:
#     자치구별(1)  자치구별(2) 2021.6  2021.7 2021.8
# 0   자치구별(1)  자치구별(2)   고등학교    고등학교   고등학교
# 1   자치구별(1)  자치구별(2)      계  국제결혼가정  외국인가정
# 2       서울시       소계   2053    1478    575
# 3       서울시      종로구     75      57     18
# 4       서울시       중구    104      77     27
# 5       서울시      용산구     86      62     24
# 6       서울시      성동구     42      33      9
# 7       서울시      광진구     69      51     18
# 8       서울시     동대문구     88      65     23
# 9       서울시      중랑구     49      39     10
# 10      서울시      성북구     63      54      9
# 11      서울시      강북구     68      61      7
# 12      서울시      도봉구     36      24     12
# 13      서울시      노원구     89      68     21
# 14      서울시      은평구    168     106     62
# 15      서울시     서대문구     40      31      9
# 16      서울시      마포구     54      40     14
# 17      서울시      양천구     77      67     10
# 18      서울시      강서구    101      89     12
# 19      서울시      구로구    228     132     96
# 20      서울시      금천구    100      59     41
# ...

# %%
culture = culture[['자치구별(2)','2021.6','2021.7','2021.8']]
culture
# Out:
#     자치구별(2) 2021.6  2021.7 2021.8
# 0   자치구별(2)   고등학교    고등학교   고등학교
# 1   자치구별(2)      계  국제결혼가정  외국인가정
# 2        소계   2053    1478    575
# 3       종로구     75      57     18
# 4        중구    104      77     27
# 5       용산구     86      62     24
# 6       성동구     42      33      9
# 7       광진구     69      51     18
# 8      동대문구     88      65     23
# 9       중랑구     49      39     10
# 10      성북구     63      54      9
# 11      강북구     68      61      7
# 12      도봉구     36      24     12
# 13      노원구     89      68     21
# 14      은평구    168     106     62
# 15     서대문구     40      31      9
# 16      마포구     54      40     14
# 17      양천구     77      67     10
# 18      강서구    101      89     12
# 19      구로구    228     132     96
# 20      금천구    100      59     41
# 21     영등포구     97      51     46
# 22      동작구     57      47     10
# 23      관악구    158      73     85
# 24      서초구     33      32      1
# 25      강남구     54      51      3
# ...

# %%
culture.rename(columns = {'자치구별(2)':'시군구', '2021.6':'다문화가족','2021.7':'국제결혼가정','2021.8':'외국인가정'},inplace=True)
culture
# Out:
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_13792\47444626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   culture.rename(columns = {'자치구별(2)':'시군구', '2021.6':'다문화가족','2021.7':'국제결혼가정','2021.8':'외국인가정'},inplace=True)
#         시군구 다문화가족  국제결혼가정  외국인가정
# 0   자치구별(2)  고등학교    고등학교   고등학교
# 1   자치구별(2)     계  국제결혼가정  외국인가정
# 2        소계  2053    1478    575
# 3       종로구    75      57     18
# 4        중구   104      77     27
# 5       용산구    86      62     24
# 6       성동구    42      33      9
# 7       광진구    69      51     18
# 8      동대문구    88      65     23
# 9       중랑구    49      39     10
# 10      성북구    63      54      9
# 11      강북구    68      61      7
# 12      도봉구    36      24     12
# 13      노원구    89      68     21
# 14      은평구   168     106     62
# ...

# %%
culture = culture.drop([0,1,2])
culture
# Out:
#      시군구 다문화가족 국제결혼가정 외국인가정
# 3    종로구    75     57    18
# 4     중구   104     77    27
# 5    용산구    86     62    24
# 6    성동구    42     33     9
# 7    광진구    69     51    18
# 8   동대문구    88     65    23
# 9    중랑구    49     39    10
# 10   성북구    63     54     9
# 11   강북구    68     61     7
# 12   도봉구    36     24    12
# 13   노원구    89     68    21
# 14   은평구   168    106    62
# 15  서대문구    40     31     9
# 16   마포구    54     40    14
# 17   양천구    77     67    10
# 18   강서구   101     89    12
# 19   구로구   228    132    96
# 20   금천구   100     59    41
# 21  영등포구    97     51    46
# 22   동작구    57     47    10
# 23   관악구   158     73    85
# 24   서초구    33     32     1
# 25   강남구    54     51     3
# 26   송파구    74     67     7
# 27   강동구    43     42     1

# %%
# 인덱스 수정 
culture.reset_index(drop=True, inplace=True)
culture
# Out:
#      시군구 다문화가족 국제결혼가정 외국인가정
# 0    종로구    75     57    18
# 1     중구   104     77    27
# 2    용산구    86     62    24
# 3    성동구    42     33     9
# 4    광진구    69     51    18
# 5   동대문구    88     65    23
# 6    중랑구    49     39    10
# 7    성북구    63     54     9
# 8    강북구    68     61     7
# 9    도봉구    36     24    12
# 10   노원구    89     68    21
# 11   은평구   168    106    62
# 12  서대문구    40     31     9
# 13   마포구    54     40    14
# 14   양천구    77     67    10
# 15   강서구   101     89    12
# 16   구로구   228    132    96
# 17   금천구   100     59    41
# 18  영등포구    97     51    46
# 19   동작구    57     47    10
# 20   관악구   158     73    85
# 21   서초구    33     32     1
# 22   강남구    54     51     3
# 23   송파구    74     67     7
# 24   강동구    43     42     1

# %%
# 저장 후 주석처리
# culture.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/서울_시군구_다문화가족.csv")
