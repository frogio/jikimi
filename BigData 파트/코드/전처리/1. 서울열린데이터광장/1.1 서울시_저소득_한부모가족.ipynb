# %% [markdown]
# # 저소득 한부모가족 데이터(서울열린데이터광장, 서울특별시)

# %%
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기 
single = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\저소득+한부모가족_20230118152512.csv",index_col = 0)
single
# Out:
#          2021 2021.1        2021.2        2021.3        2021.4        2021.5  \
# 자치구(1)
# 자치구(1)     합계     합계  한부모가족지원법 수급자  한부모가족지원법 수급자  한부모가족지원법 수급자  한부모가족지원법 수급자
# 자치구(1)     합계     합계            합계            합계          재가보호          재가보호
# 자치구(1)    가구수   가구원수           가구수          가구원수           가구수          가구원수
# 계       29486  67828          4454         15050          4407         15003
# 종로구       310    693            96           268            94           266
# 중구        335    746            72           233            70           231
# 용산구       557   1152            85           253            85           253
# 성동구       640   1448           100           350            88           338
# 광진구      1111   2605           170           582           170           582
# 동대문구     1067   2497           169           614           169           614
# 중랑구      2087   4909           311          1052           311          1052
# ...

# %%
single.columns
# Out:
# Index(['2021', '2021.1', '2021.2', '2021.3', '2021.4', '2021.5', '2021.6',
#        '2021.7', '2021.8', '2021.9', '2021.10', '2021.11', '2021.12',
#        '2021.13'],
#       dtype='object')

# %%
single_choice = single[['2021','2021.1','2021.2','2021.3','2021.4','2021.5','2021.10','2021.11']]
single_choice
# Out:
#          2021 2021.1        2021.2        2021.3        2021.4        2021.5  \
# 자치구(1)
# 자치구(1)     합계     합계  한부모가족지원법 수급자  한부모가족지원법 수급자  한부모가족지원법 수급자  한부모가족지원법 수급자
# 자치구(1)     합계     합계            합계            합계          재가보호          재가보호
# 자치구(1)    가구수   가구원수           가구수          가구원수           가구수          가구원수
# 계       29486  67828          4454         15050          4407         15003
# 종로구       310    693            96           268            94           266
# 중구        335    746            72           233            70           231
# 용산구       557   1152            85           253            85           253
# 성동구       640   1448           100           350            88           338
# 광진구      1111   2605           170           582           170           582
# 동대문구     1067   2497           169           614           169           614
# 중랑구      2087   4909           311          1052           311          1052
# ...

# %%
# 인덱스 수정 
single_choice.reset_index(drop=False, inplace=True)
single_choice
# Out:
#     자치구(1)   2021 2021.1        2021.2        2021.3        2021.4  \
# 0   자치구(1)     합계     합계  한부모가족지원법 수급자  한부모가족지원법 수급자  한부모가족지원법 수급자
# 1   자치구(1)     합계     합계            합계            합계          재가보호
# 2   자치구(1)    가구수   가구원수           가구수          가구원수           가구수
# 3        계  29486  67828          4454         15050          4407
# 4      종로구    310    693            96           268            94
# 5       중구    335    746            72           233            70
# 6      용산구    557   1152            85           253            85
# 7      성동구    640   1448           100           350            88
# 8      광진구   1111   2605           170           582           170
# 9     동대문구   1067   2497           169           614           169
# 10     중랑구   2087   4909           311          1052           311
# 11     성북구   1313   3028           193           676           189
# 12     강북구   1707   3955           262           910           262
# ...

# %%
single_choice = single_choice[['자치구(1)','2021','2021.1','2021.5','2021.11']]
single_choice
# Out:
#     자치구(1)   2021 2021.1        2021.5        2021.11
# 0   자치구(1)     합계     합계  한부모가족지원법 수급자  국민기초생활보장법 수급자
# 1   자치구(1)     합계     합계          재가보호  국민기초생활보장법 수급자
# 2   자치구(1)    가구수   가구원수          가구원수           가구원수
# 3        계  29486  67828         15003          52778
# 4      종로구    310    693           266            425
# 5       중구    335    746           231            513
# 6      용산구    557   1152           253            899
# 7      성동구    640   1448           338           1098
# 8      광진구   1111   2605           582           2023
# 9     동대문구   1067   2497           614           1883
# 10     중랑구   2087   4909          1052           3857
# 11     성북구   1313   3028           672           2352
# 12     강북구   1707   3955           910           3045
# 13     도봉구   1531   3610           887           2723
# 14     노원구   2240   5071           799           4272
# 15     은평구   1897   4330           860           3470
# ...

# %%
single_choice = single_choice.rename(columns = {'자치구(1)':'시군구','2021':'가구수', '2021.1':'가구원수','2021.5':'한부모가족지원법수급자_재가보호_가구원수','2021.11':'국민기초생활보장법수급자_가구원수'})
single_choice
# Out:
#        시군구    가구수   가구원수 한부모가족지원법수급자_재가보호_가구원수 국민기초생활보장법수급자_가구원수
# 0   자치구(1)     합계     합계          한부모가족지원법 수급자     국민기초생활보장법 수급자
# 1   자치구(1)     합계     합계                  재가보호     국민기초생활보장법 수급자
# 2   자치구(1)    가구수   가구원수                  가구원수              가구원수
# 3        계  29486  67828                 15003             52778
# 4      종로구    310    693                   266               425
# 5       중구    335    746                   231               513
# 6      용산구    557   1152                   253               899
# 7      성동구    640   1448                   338              1098
# 8      광진구   1111   2605                   582              2023
# 9     동대문구   1067   2497                   614              1883
# 10     중랑구   2087   4909                  1052              3857
# 11     성북구   1313   3028                   672              2352
# 12     강북구   1707   3955                   910              3045
# ...

# %%
single_choice.reset_index(drop=True, inplace=True)
single_choice
# Out:
#        시군구    가구수   가구원수 한부모가족지원법수급자_재가보호_가구원수 국민기초생활보장법수급자_가구원수
# 0   자치구(1)     합계     합계          한부모가족지원법 수급자     국민기초생활보장법 수급자
# 1   자치구(1)     합계     합계                  재가보호     국민기초생활보장법 수급자
# 2   자치구(1)    가구수   가구원수                  가구원수              가구원수
# 3        계  29486  67828                 15003             52778
# 4      종로구    310    693                   266               425
# 5       중구    335    746                   231               513
# 6      용산구    557   1152                   253               899
# 7      성동구    640   1448                   338              1098
# 8      광진구   1111   2605                   582              2023
# 9     동대문구   1067   2497                   614              1883
# 10     중랑구   2087   4909                  1052              3857
# 11     성북구   1313   3028                   672              2352
# 12     강북구   1707   3955                   910              3045
# ...

# %%
single_choice = single_choice.loc[4:28]
single_choice = single_choice.reset_index(drop=True)
single_choice
# Out:
#      시군구   가구수  가구원수 한부모가족지원법수급자_재가보호_가구원수 국민기초생활보장법수급자_가구원수
# 0    종로구   310   693                   266               425
# 1     중구   335   746                   231               513
# 2    용산구   557  1152                   253               899
# 3    성동구   640  1448                   338              1098
# 4    광진구  1111  2605                   582              2023
# 5   동대문구  1067  2497                   614              1883
# 6    중랑구  2087  4909                  1052              3857
# 7    성북구  1313  3028                   672              2352
# 8    강북구  1707  3955                   910              3045
# 9    도봉구  1531  3610                   887              2723
# 10   노원구  2240  5071                   799              4272
# 11   은평구  1897  4330                   860              3470
# 12  서대문구   886  2037                   529              1506
# 13   마포구   812  1828                   484              1340
# ...

# %%
# 저장 후 주석처리
# single_choice.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/서울_시군구_저소득_한부모가족.csv")
