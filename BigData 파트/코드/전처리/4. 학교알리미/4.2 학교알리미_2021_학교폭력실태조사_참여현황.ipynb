# %% [markdown]
# # 학교알리미 학교폭력실태조사 참여현황 데이터
# - 데이터
#     - 학교알리미_2021_서울_학교폭력실태조사_참여현황.csv(DataPreprocessing)
#     - 학교알리미_2021_서울_시군구별_학교폭력실태조사_참여현황.csv(DataPreprocessing)
#     - 학교알리미_2021_서울_시군구별_고등학교_학생_수.csv(DataPreprocessing)

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/강남구_학교폭력_실태조사_조사참여현황.xlsx")
df2 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/강동구_학교폭력_실태조사_조사참여현황.xlsx")
df3 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/강북구_학교폭력_실태조사_조사참여현황.xlsx")
df4 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/강서구_학교폭력_실태조사_조사참여현황.xlsx")
df5 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/관악구_학교폭력_실태조사_조사참여현황.xlsx")
df6 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/광진구_학교폭력_실태조사_조사참여현황.xlsx")
df7 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/구로구_학교폭력_실태조사_조사참여현황.xlsx")
df8 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/금천구_학교폭력_실태조사_조사참여현황.xlsx")
df9 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/노원구_학교폭력_실태조사_조사참여현황.xlsx")
df10 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/도봉구_학교폭력_실태조사_조사참여현황.xlsx")
df11 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/동대문구_학교폭력_실태조사_조사참여현황.xlsx")
df12 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/동작구_학교폭력_실태조사_조사참여현황.xlsx")
df13 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/마포구_학교폭력_실태조사_조사참여현황.xlsx")
df14 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/서대문구_학교폭력_실태조사_조사참여현황.xlsx")
df15 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/서초구_학교폭력_실태조사_조사참여현황.xlsx")
df16 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/성동구_학교폭력_실태조사_조사참여현황.xlsx")
df17 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/성북구_학교폭력_실태조사_조사참여현황.xlsx")
df18 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/송파구_학교폭력_실태조사_조사참여현황.xlsx")
df19 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/양천구_학교폭력_실태조사_조사참여현황.xlsx")
df20 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/영등포구_학교폭력_실태조사_조사참여현황.xlsx")
df21 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/용산구_학교폭력_실태조사_조사참여현황.xlsx")
df22 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/은평구_학교폭력_실태조사_조사참여현황.xlsx")
df23 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/종로구_학교폭력_실태조사_조사참여현황.xlsx")
df24 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/중구_학교폭력_실태조사_조사참여현황.xlsx")
df25 = pd.read_excel("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/조사 참여 현황 - 2021/중랑구_학교폭력_실태조사_조사참여현황.xlsx")

# %%
investigation = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,
                           df11,df12,df13,df14,df15,df16,df17,df18,
                           df19,df20,df21,df22,df23,df24,df25], ignore_index=True)
investigation
# Out:
#      Unnamed: 0    구               학교명       구분 대상 학생 수 학생 수 참여율(고등학교별 전국참여율)  \
# 0             0  강남구            개포고등학교  2021학년도     640  584     91.3(  85.2)
# 1             1  강남구            경기고등학교  2021학년도   1,100  689     62.6(  85.2)
# 2             2  강남구          경기여자고등학교  2021학년도   1,095  962     87.9(  85.2)
# 3             3  강남구          국립국악고등학교  2021학년도     438  372     84.9(  85.2)
# 4             4  강남구  단국대학교부속소프트웨어고등학교  2021학년도     267  261     97.8(  85.2)
# ..          ...  ...               ...      ...     ...  ...              ...
# 315           5  중랑구            원묵고등학교  2021학년도     643  591     91.9(  85.2)
# 316           6  중랑구  이화여자대학교병설미디어고등학교  2021학년도     537  431     80.3(  85.2)
# 317           7  중랑구            중화고등학교  2021학년도     542  345     63.7(  85.2)
# 318           8  중랑구            태릉고등학교  2021학년도     708  577     81.5(  85.2)
# 319           9  중랑구          혜원여자고등학교  2021학년도     588  407     69.2(  85.2)
#
#      피해 응답 학생 수
# ...

# %%
investigation.drop(['Unnamed: 0'], axis = 1,inplace=True)
investigation
# Out:
#        구               학교명       구분 대상 학생 수 학생 수 참여율(고등학교별 전국참여율)  피해 응답 학생 수
# 0    강남구            개포고등학교  2021학년도     640  584     91.3(  85.2)           2
# 1    강남구            경기고등학교  2021학년도   1,100  689     62.6(  85.2)           3
# 2    강남구          경기여자고등학교  2021학년도   1,095  962     87.9(  85.2)           1
# 3    강남구          국립국악고등학교  2021학년도     438  372     84.9(  85.2)           0
# 4    강남구  단국대학교부속소프트웨어고등학교  2021학년도     267  261     97.8(  85.2)           0
# ..   ...               ...      ...     ...  ...              ...         ...
# 315  중랑구            원묵고등학교  2021학년도     643  591     91.9(  85.2)           0
# 316  중랑구  이화여자대학교병설미디어고등학교  2021학년도     537  431     80.3(  85.2)           0
# 317  중랑구            중화고등학교  2021학년도     542  345     63.7(  85.2)           2
# 318  중랑구            태릉고등학교  2021학년도     708  577     81.5(  85.2)           1
# 319  중랑구          혜원여자고등학교  2021학년도     588  407     69.2(  85.2)           0
#
# [320 rows x 7 columns]

# %%
investigation.rename(columns = {'구':'시군구'},inplace=True)
investigation
# Out:
#      시군구               학교명       구분 대상 학생 수 학생 수 참여율(고등학교별 전국참여율)  피해 응답 학생 수
# 0    강남구            개포고등학교  2021학년도     640  584     91.3(  85.2)           2
# 1    강남구            경기고등학교  2021학년도   1,100  689     62.6(  85.2)           3
# 2    강남구          경기여자고등학교  2021학년도   1,095  962     87.9(  85.2)           1
# 3    강남구          국립국악고등학교  2021학년도     438  372     84.9(  85.2)           0
# 4    강남구  단국대학교부속소프트웨어고등학교  2021학년도     267  261     97.8(  85.2)           0
# ..   ...               ...      ...     ...  ...              ...         ...
# 315  중랑구            원묵고등학교  2021학년도     643  591     91.9(  85.2)           0
# 316  중랑구  이화여자대학교병설미디어고등학교  2021학년도     537  431     80.3(  85.2)           0
# 317  중랑구            중화고등학교  2021학년도     542  345     63.7(  85.2)           2
# 318  중랑구            태릉고등학교  2021학년도     708  577     81.5(  85.2)           1
# 319  중랑구          혜원여자고등학교  2021학년도     588  407     69.2(  85.2)           0
#
# [320 rows x 7 columns]

# %%
investigation
# Out:
#      시군구               학교명       구분 대상 학생 수 학생 수 참여율(고등학교별 전국참여율)  피해 응답 학생 수
# 0    강남구            개포고등학교  2021학년도     640  584     91.3(  85.2)           2
# 1    강남구            경기고등학교  2021학년도   1,100  689     62.6(  85.2)           3
# 2    강남구          경기여자고등학교  2021학년도   1,095  962     87.9(  85.2)           1
# 3    강남구          국립국악고등학교  2021학년도     438  372     84.9(  85.2)           0
# 4    강남구  단국대학교부속소프트웨어고등학교  2021학년도     267  261     97.8(  85.2)           0
# ..   ...               ...      ...     ...  ...              ...         ...
# 315  중랑구            원묵고등학교  2021학년도     643  591     91.9(  85.2)           0
# 316  중랑구  이화여자대학교병설미디어고등학교  2021학년도     537  431     80.3(  85.2)           0
# 317  중랑구            중화고등학교  2021학년도     542  345     63.7(  85.2)           2
# 318  중랑구            태릉고등학교  2021학년도     708  577     81.5(  85.2)           1
# 319  중랑구          혜원여자고등학교  2021학년도     588  407     69.2(  85.2)           0
#
# [320 rows x 7 columns]

# %%
investigation.replace('은일정보산업고등학교', '유한공업고등학교',inplace=True)

# %%
# 저장 후 주석처리
# investigation.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/학교알리미_2021_서울_학교폭력실태조사_참여현황.csv", index=False)

# %% [markdown]
# # 시군구 별 피해 응답 학생 수

# %%
import pandas as pd
import numpy as np

# %%
# 2021 학교폭력실태조사 참여현황 데이터 불러오기 
answer = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\학교알리미_2021_서울_학교폭력실태조사_참여현황.csv")
answer['피해 응답 학생 수'].value_counts()
# Out:
# 0     135
# 1      94
# 2      58
# 3      22
# 4       9
# 11      1
# 5       1
# Name: 피해 응답 학생 수, dtype: int64

# %%
answer_df = answer.groupby(["시군구"]).agg({"피해 응답 학생 수":"sum"}).reset_index()
answer_df
# Out:
#      시군구  피해 응답 학생 수
# 0    강남구          19
# 1    강동구          12
# 2    강북구           9
# 3    강서구          28
# 4    관악구          17
# 5    광진구          13
# 6    구로구          13
# 7    금천구           8
# 8    노원구          42
# 9    도봉구           7
# 10  동대문구           9
# 11   동작구           4
# 12   마포구          10
# 13  서대문구           7
# 14   서초구          13
# 15   성동구          12
# 16   성북구          10
# 17   송파구          14
# 18   양천구          21
# 19  영등포구           8
# 20   용산구           7
# 21   은평구          13
# 22   종로구          18
# 23    중구           7
# 24   중랑구           7

# %%
# 저장 후 주석처리
# answer_df.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/학교알리미_2021_서울_시군구별_학교폭력실태조사_참여현황.csv", index=False)

# %% [markdown]
# # 시군구 별 대상 학생 수

# %%
import pandas as pd
import numpy as np
import re

# %%
# 2021 학교폭력실태조사 참여현황 데이터 불러오기 
answer = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\학교알리미_2021_서울_학교폭력실태조사_참여현황.csv")
answer
# Out:
#      시군구               학교명       구분 대상 학생 수 학생 수 참여율(고등학교별 전국참여율)  피해 응답 학생 수
# 0    강남구            개포고등학교  2021학년도     640  584     91.3(  85.2)           2
# 1    강남구            경기고등학교  2021학년도   1,100  689     62.6(  85.2)           3
# 2    강남구          경기여자고등학교  2021학년도   1,095  962     87.9(  85.2)           1
# 3    강남구          국립국악고등학교  2021학년도     438  372     84.9(  85.2)           0
# 4    강남구  단국대학교부속소프트웨어고등학교  2021학년도     267  261     97.8(  85.2)           0
# ..   ...               ...      ...     ...  ...              ...         ...
# 315  중랑구            원묵고등학교  2021학년도     643  591     91.9(  85.2)           0
# 316  중랑구  이화여자대학교병설미디어고등학교  2021학년도     537  431     80.3(  85.2)           0
# 317  중랑구            중화고등학교  2021학년도     542  345     63.7(  85.2)           2
# 318  중랑구            태릉고등학교  2021학년도     708  577     81.5(  85.2)           1
# 319  중랑구          혜원여자고등학교  2021학년도     588  407     69.2(  85.2)           0
#
# [320 rows x 7 columns]

# %%
answer['대상학생수_int'] = answer['대상 학생 수'].str.replace(',', '').astype('int64')

# %%
answer.dtypes
# Out:
# 시군구                 object
# 학교명                 object
# 구분                  object
# 대상 학생 수             object
# 학생 수                object
# 참여율(고등학교별 전국참여율)    object
# 피해 응답 학생 수           int64
# 대상학생수_int            int64
# dtype: object

# %%
answer_df = answer.groupby(["시군구"]).agg({"대상학생수_int":"sum"}).reset_index()
answer_df
# Out:
#      시군구  대상학생수_int
# 0    강남구      17609
# 1    강동구      10734
# 2    강북구       5240
# 3    강서구      14167
# 4    관악구       8850
# 5    광진구       7308
# 6    구로구       9037
# 7    금천구       3881
# 8    노원구      19146
# 9    도봉구       6342
# 10  동대문구       6653
# 11   동작구       5762
# 12   마포구       5861
# 13  서대문구       4912
# 14   서초구       9542
# 15   성동구       4040
# 16   성북구       8013
# 17   송파구      14186
# 18   양천구      12085
# 19  영등포구       5678
# 20   용산구       5028
# 21   은평구      12213
# 22   종로구       8051
# 23    중구       6190
# 24   중랑구       5893

# %%
# 저장 후 주석처리
# answer_df.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/학교알리미_2021_서울_시군구별_고등학교_학생_수.csv", index=False)
