# %% [markdown]
# # 학교기본정보 데이터(나이스)

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
# 데이터 불러오기 
school = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/학교기본정보.csv")

# %%
school.shape
# Out:
# (1421, 25)

# %%
school
# Out:
#      시도교육청코드    시도교육청명   표준학교코드      학교명                          영문학교명 학교종류명  \
# 0        B10  서울특별시교육청  7010057   가락고등학교              Garak High School  고등학교
# 1        B10  서울특별시교육청  7130165    가락중학교            Karak Middle School   중학교
# 2        B10  서울특별시교육청  7041164    가산중학교            Gasan Middle School   중학교
# 3        B10  서울특별시교육청  7130166    가원중학교            Gawon Middle School   중학교
# 4        B10  서울특별시교육청  7011169  가재울고등학교            Gajaeul High School  고등학교
# ...      ...       ...      ...      ...                            ...   ...
# 1416     B10  서울특별시교육청  7021149  휘경여자중학교  Hwikyung Girls’ Middle School   중학교
# 1417     B10  서울특별시교육청  7021150    휘경중학교         Hwigyong Middle School   중학교
# 1418     B10  서울특별시교육청  7010268   휘문고등학교            Whimoon High School  고등학교
# 1419     B10  서울특별시교육청  7091457    휘문중학교          Whimoon Middle School   중학교
# 1420     B10  서울특별시교육청  7011113   휘봉고등학교            HWIBONG High School  고등학교
#
# ...

# %%
school.isnull().sum()
# Out:
# 시도교육청코드           0
# 시도교육청명            0
# 표준학교코드            0
# 학교명               0
# 영문학교명             3
# 학교종류명             0
# 소재지명              0
# 관할조직명             0
# 설립명               0
# 도로명우편번호           0
# 도로명주소             0
# 도로명상세주소           0
# 전화번호              0
# 홈페이지주소            1
# 남녀공학구분명           0
# 팩스번호              1
# 고등학교구분명        1088
# 산업체특별학급존재여부       0
# 고등학교일반실업구분명      30
# 특수목적고등학교계열명    1399
# 입시전후기구분명          0
# 주야구분명             0
# 설립일자              0
# 개교기념일             0
# 수정일               0
# dtype: int64

# %%
# 고등학교 구분명 결측치 제거 
high_school = school.dropna(subset=['고등학교구분명'])

# 인덱스 수정 
high_school.reset_index(drop=False, inplace=True)

# 'index' 컬럼 drop
high_school = high_school.drop(['index'],axis='columns')
high_school
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 328     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 329     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 330     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 331     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 332     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명     관할조직명 설립명  도로명우편번호  ...          팩스번호 고등학교구분명  \
# ...

# %%
# 도로명 주소 시군구 확인 
high_school['도로명주소'].apply(lambda x:x.split()[1])
# Out:
# 0       송파구
# 1      서대문구
# 2       강동구
# 3       양천구
# 4       강서구
#        ...
# 328     도봉구
# 329    동대문구
# 330    동대문구
# 331     강남구
# 332    동대문구
# Name: 도로명주소, Length: 333, dtype: object

# %%
# 시군구 컬럼 추가하기 
high_school['시군구'] = high_school['도로명주소'].apply(lambda x:x.split()[1])
high_school
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 328     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 329     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 330     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 331     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 332     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명     관할조직명 설립명  도로명우편번호  ... 고등학교구분명 산업체특별학급존재여부 고등학교일반실업구분명  \
# ...

# %%
# school 컬럼 확인하기 
high_school.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '관할조직명',
#        '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소', '남녀공학구분명',
#        '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명', '특수목적고등학교계열명',
#        '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '수정일', '시군구'],
#       dtype='object')

# %%
# school 컬럼 변경하기
high_school = high_school[['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구', '관할조직명',
       '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소', '남녀공학구분명',
       '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명', '특수목적고등학교계열명',
       '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '수정일']]
high_school
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 328     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 329     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 330     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 331     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 332     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          팩스번호 고등학교구분명 산업체특별학급존재여부  \
# ...

# %%
# 저장 후 주석처리
# high_school.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/나이스_서울_학교기본정보.csv")

# %%
# 데이터 불러오기 
high_school = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/나이스_서울_학교기본정보.csv",index_col = 0)
high_school
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 328     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 329     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 330     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 331     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 332     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          팩스번호 고등학교구분명 산업체특별학급존재여부  \
# ...

# %%
# # 나이스_학교기본정보 / 학교알리미_학교폭력실태조사 학교명 비교 

# # 데이터 불러오기 
# school_info = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/Crawling/학교알리미_2021_서울_학교폭력실태조사_참여현황.csv")

# school_info_name = pd.DataFrame(school_info['학교명'])
# high_school_name = pd.DataFrame(high_school['학교명'])

# def GetDifferences(school_info_name, high_school_name):
#   df = pd.concat([school_info_name, high_school_name]).reset_index(drop=True)
#   idx = [diff[0] for diff in df.groupby(list(df.columns)).groups.values() if len(diff) == 1]
#   return df.reindex(idx)

# GetDifferences(school_info_name, high_school_name)
# Out:
#                     학교명
# 332  경기여자고등학교부설방송통신고등학교
# 334    경동고등학교부설방송통신고등학교
# 337    경복고등학교부설방송통신고등학교
# 369          금천문화예술정보학교
# 394         덕수고등학교(일반고)
# 519  수도여자고등학교부설방송통신고등학교
# 548   영등포고등학교부설방송통신고등학교
# 563              오디세이학교
# 573            유한공업고등학교
# 105          은일정보산업고등학교
# 618    학력인정 성지고등학교(2년제)
# 619    학력인정 성지중.고등학교(고)
# 620  학력인정 일성여자고등학교(2년제)
# 621    학력인정 진형고등학교(2년제)
# 622    학력인정 청암고등학교(2년제)

# %%
# 삭제할 학교명 
# 덕수고등학교(일반고)
# 오디세이학교
# 금천문화예술정보학교
# 방송통신
# 학력인정

# %%
# 1. 덕수고등학교(일반고) 삭제 
high_school.loc[74]

# 2. 오디세이학교 삭제
high_school.loc[243]

# 3. 금천문화예술정보학교 삭제
high_school.loc[49]

# 4. 경기여자고등학교부설방송통신고등학교 삭제
high_school.loc[12]

# 5. 경동고등학교부설방송통신고등학교 삭제
high_school.loc[14]

# 6. 경복고등학교부설방송통신고등학교
high_school.loc[17]

# 7. 수도여자고등학교부설방송통신고등학교
high_school.loc[199]

# 8. 영등포고등학교부설방송통신고등학교
high_school.loc[228]

# 9. 학력인정 성지고등학교(2년제)
high_school.loc[298]

# 10. 학력인정 성지중.고등학교(고)
high_school.loc[299]

# 11. 학력인정 일성여자고등학교(2년제)
high_school.loc[300]

# 12. 학력인정 진형고등학교(2년제)
high_school.loc[301]

# 12. 학력인정 청암고등학교(2년제)
high_school.loc[302]

high_school_drop = high_school.drop(index=[74,243, 12, 49, 14, 17, 199, 228, 298, 299, 300, 301, 302])
high_school_drop
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 328     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 329     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 330     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 331     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 332     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          팩스번호 고등학교구분명 산업체특별학급존재여부  \
# ...

# %%
# 인덱스 수정 
high_school_drop.reset_index(drop=False, inplace=True)

# %%
# 'index' 컬럼 drop
high_school_drop = high_school_drop.drop(['index'],axis='columns')
high_school_drop
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          팩스번호 고등학교구분명 산업체특별학급존재여부  \
# ...

# %%
# 저장 후 주석처리
# high_school_drop.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/나이스_서울_전체_학교기본정보.csv")
