# %% [markdown]
# # 종합지표

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 그래프 시각화 라이브러리 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# C:\Users\ppi06\anaconda3\envs\data_venv\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 학교폭력위험도에 환경지표, 위해지표, 경감지표가 각각 얼만큼의 비중을 차지하는지 가중치 부여

# %% [markdown]
# ## 상관계수의 크기로 각각의 지표에 가중치 부여

# %%
# 환경지표
(0.569231+0.641538+(0.050769)+0.511252+0.693846+0.480769+(0.456154)+(0.071538))/8

# 위해지표
(0.165095+(0.220085)+0.102426+0.534539+(0.228934))/5

# 경감지표
((0.366154)+0.253272+0.173077)/3

weight = pd.DataFrame({'환경지표':[(0.569231+0.641538+(0.050769)+0.511252+0.693846+0.480769+(0.456154)+(0.071538))/8],
                             '위해지표':[(0.165095+(0.220085)+0.102426+0.534539+(0.228934))/5],
                             '경감지표':[((0.366154)+0.253272+0.173077)/3]})
weight['sum'] = weight.sum(axis=1)
weight_new= weight.apply(lambda x : x/weight['sum'])
weight_new
# Out:
#        환경지표      위해지표      경감지표  sum
# 0  0.457842  0.263726  0.278432  1.0

# %% [markdown]
# # 환경지표

# %%
Environmental_indicators = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_환경지표.csv",index_col=0)
Environmental_indicators
# Out:
#      시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 0    강남구   19.071217             3         매우낮음
# 1    강동구   55.148267             2           보통
# 2    강북구  105.369939             1         매우높음
# 3    강서구   77.831186             1         매우높음
# 4    관악구   77.867433             4           높음
# 5    광진구   60.193732             2           보통
# 6    구로구   70.972259             4           높음
# 7    금천구   90.229114             1         매우높음
# 8    노원구   73.827367             2           보통
# 9    도봉구   89.946627             1         매우높음
# 10  동대문구   58.574818             2           보통
# 11   동작구   41.254694             2           보통
# 12   마포구   36.219280             3         매우낮음
# 13  서대문구   46.193799             2           보통
# 14   서초구   20.295262             3         매우낮음
# 15   성동구   38.346846             3         매우낮음
# 16   성북구   50.472787             2           보통
# 17   송파구   48.715229             3         매우낮음
# 18   양천구   65.103834             2           보통
# ...

# %% [markdown]
# # 경감지표

# %%
Alleviate_indicators = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_경감지표.csv",index_col=0)
Alleviate_indicators
# Out:
#           학교명  경감지표_cluster  경감지표_score 경감지표_학교폭력위험도
# 0      가락고등학교             0          20   매우 안전하지 않음
# 1     가재울고등학교             0          20   매우 안전하지 않음
# 2      강동고등학교             0          20   매우 안전하지 않음
# 3      강서고등학교             1         100        매우 안전
# 4    강서공업고등학교             3          40      안전하지 않음
# ..        ...           ...         ...          ...
# 315    효문고등학교             0          20   매우 안전하지 않음
# 316  휘경공업고등학교             3          40      안전하지 않음
# 317  휘경여자고등학교             3          40      안전하지 않음
# 318    휘문고등학교             4          60           보통
# 319    휘봉고등학교             3          40      안전하지 않음
#
# [320 rows x 4 columns]

# %% [markdown]
# # 위해지표

# %%
Hazard_indicators = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_위해지표.csv",index_col=0)
Hazard_indicators
# Out:
#           학교명  위해지표_cluster  위해지표_score 위해지표_학교폭력위험도
# 0      가락고등학교             5          20           안전
# 1     가재울고등학교             1         100        매우 위험
# 2      강동고등학교             2          60           주의
# 3      강서고등학교             1         100        매우 위험
# 4    강서공업고등학교             4          40           보통
# ..        ...           ...         ...          ...
# 315    효문고등학교             4          40           보통
# 316  휘경공업고등학교             4          40           보통
# 317  휘경여자고등학교             1         100        매우 위험
# 318    휘문고등학교             4          40           보통
# 319    휘봉고등학교             0           0        매우 안전
#
# [320 rows x 4 columns]

# %% [markdown]
# # 학교정보

# %%
school = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_정보.csv",index_col=0)
school_data = school[['학교명','시군구']]
school_data
# Out:
#           학교명   시군구
# 0      가락고등학교   송파구
# 1     가재울고등학교  서대문구
# 2      강동고등학교   강동구
# 3      강서고등학교   양천구
# 4    강서공업고등학교   강서구
# ..        ...   ...
# 315    효문고등학교   도봉구
# 316  휘경공업고등학교  동대문구
# 317  휘경여자고등학교  동대문구
# 318    휘문고등학교   강남구
# 319    휘봉고등학교  동대문구
#
# [320 rows x 2 columns]

# %% [markdown]
# # 환경지표 + 위해지표 + 경감지표 +학교정보

# %%
data1 = pd.merge(school_data, Environmental_indicators, on=['시군구'], how='outer', sort=True)
data2 = pd.merge(data1, Hazard_indicators, on=['학교명'], how='outer', sort=True)
data3 = pd.merge(data2, Alleviate_indicators, on=['학교명'], how='outer', sort=True)
data3= data3[['학교명', '시군구', '환경지표_score', '환경지표_cluster', '환경지표_학교폭력위험도','위해지표_score',
       '위해지표_cluster','위해지표_학교폭력위험도', '경감지표_score','경감지표_cluster','경감지표_학교폭력위험도']]
data3
# Out:
#           학교명   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도  위해지표_score  \
# 0      가락고등학교   송파구   48.715229             3         매우낮음          20
# 1     가재울고등학교  서대문구   46.193799             2           보통         100
# 2      강동고등학교   강동구   55.148267             2           보통          60
# 3      강서고등학교   양천구   65.103834             2           보통         100
# 4    강서공업고등학교   강서구   77.831186             1         매우높음          40
# ..        ...   ...         ...           ...          ...         ...
# 315    효문고등학교   도봉구   89.946627             1         매우높음          40
# 316  휘경공업고등학교  동대문구   58.574818             2           보통          40
# 317  휘경여자고등학교  동대문구   58.574818             2           보통         100
# 318    휘문고등학교   강남구   19.071217             3         매우낮음          40
# 319    휘봉고등학교  동대문구   58.574818             2           보통           0
#
#      위해지표_cluster 위해지표_학교폭력위험도  경감지표_score  경감지표_cluster 경감지표_학교폭력위험도
# ...

# %%
data3['total_score'] = data3['환경지표_score']*0.457842 + data3['위해지표_score']*0.263726 - data3['경감지표_score']*0.278432
data3
# Out:
#           학교명   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도  위해지표_score  \
# 0      가락고등학교   송파구   48.715229             3         매우낮음          20
# 1     가재울고등학교  서대문구   46.193799             2           보통         100
# 2      강동고등학교   강동구   55.148267             2           보통          60
# 3      강서고등학교   양천구   65.103834             2           보통         100
# 4    강서공업고등학교   강서구   77.831186             1         매우높음          40
# ..        ...   ...         ...           ...          ...         ...
# 315    효문고등학교   도봉구   89.946627             1         매우높음          40
# 316  휘경공업고등학교  동대문구   58.574818             2           보통          40
# 317  휘경여자고등학교  동대문구   58.574818             2           보통         100
# 318    휘문고등학교   강남구   19.071217             3         매우낮음          40
# 319    휘봉고등학교  동대문구   58.574818             2           보통           0
#
#      위해지표_cluster 위해지표_학교폭력위험도  경감지표_score  경감지표_cluster 경감지표_학교폭력위험도  \
# ...

# %%
# total_score 0~100으로 스케일링 
data3['total_score'] -= data3['total_score'].min()
data3['total_score_0_to_100'] = data3['total_score'] * (100 / data3['total_score'].max())
data3['total_score_0_to_100']
data3
# Out:
#           학교명   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도  위해지표_score  \
# 0      가락고등학교   송파구   48.715229             3         매우낮음          20
# 1     가재울고등학교  서대문구   46.193799             2           보통         100
# 2      강동고등학교   강동구   55.148267             2           보통          60
# 3      강서고등학교   양천구   65.103834             2           보통         100
# 4    강서공업고등학교   강서구   77.831186             1         매우높음          40
# ..        ...   ...         ...           ...          ...         ...
# 315    효문고등학교   도봉구   89.946627             1         매우높음          40
# 316  휘경공업고등학교  동대문구   58.574818             2           보통          40
# 317  휘경여자고등학교  동대문구   58.574818             2           보통         100
# 318    휘문고등학교   강남구   19.071217             3         매우낮음          40
# 319    휘봉고등학교  동대문구   58.574818             2           보통           0
#
#      위해지표_cluster 위해지표_학교폭력위험도  경감지표_score  경감지표_cluster 경감지표_학교폭력위험도  \
# ...

# %%
data3.drop(['total_score'], axis=1, inplace=True)

# %%
data3.rename(columns={'total_score_0_to_100':'total_score'}, inplace=True)

# %%
data3
# Out:
#           학교명   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도  위해지표_score  \
# 0      가락고등학교   송파구   48.715229             3         매우낮음          20
# 1     가재울고등학교  서대문구   46.193799             2           보통         100
# 2      강동고등학교   강동구   55.148267             2           보통          60
# 3      강서고등학교   양천구   65.103834             2           보통         100
# 4    강서공업고등학교   강서구   77.831186             1         매우높음          40
# ..        ...   ...         ...           ...          ...         ...
# 315    효문고등학교   도봉구   89.946627             1         매우높음          40
# 316  휘경공업고등학교  동대문구   58.574818             2           보통          40
# 317  휘경여자고등학교  동대문구   58.574818             2           보통         100
# 318    휘문고등학교   강남구   19.071217             3         매우낮음          40
# 319    휘봉고등학교  동대문구   58.574818             2           보통           0
#
#      위해지표_cluster 위해지표_학교폭력위험도  경감지표_score  경감지표_cluster 경감지표_학교폭력위험도  \
# ...

# %%
percent = [0.20, 0.40, 0.60, 0.80]

# %%
data3['total_score'].describe(percentiles = percent)
# Out:
# count    320.000000
# mean      56.300208
# std       18.538313
# min        0.000000
# 20%       40.477257
# 40%       51.627009
# 50%       55.861178
# 60%       61.481197
# 80%       71.747387
# max      100.000000
# Name: total_score, dtype: float64

# %%
# total_Score 기준 상위20%
def group(score):
    if score>71.747387: return '매우위험'
    elif score>61.481197: return '위험'
    elif score>51.627009: return '보통'
    elif score>40.477257: return '안전'
    else: return '매우안전'

score_group = data3['total_score'].apply(lambda x:group(x))
data3['종합_위험도'] = score_group
data3
# Out:
#           학교명   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도  위해지표_score  \
# 0      가락고등학교   송파구   48.715229             3         매우낮음          20
# 1     가재울고등학교  서대문구   46.193799             2           보통         100
# 2      강동고등학교   강동구   55.148267             2           보통          60
# 3      강서고등학교   양천구   65.103834             2           보통         100
# 4    강서공업고등학교   강서구   77.831186             1         매우높음          40
# ..        ...   ...         ...           ...          ...         ...
# 315    효문고등학교   도봉구   89.946627             1         매우높음          40
# 316  휘경공업고등학교  동대문구   58.574818             2           보통          40
# 317  휘경여자고등학교  동대문구   58.574818             2           보통         100
# 318    휘문고등학교   강남구   19.071217             3         매우낮음          40
# 319    휘봉고등학교  동대문구   58.574818             2           보통           0
#
#      위해지표_cluster 위해지표_학교폭력위험도  경감지표_score  경감지표_cluster 경감지표_학교폭력위험도  \
# ...

# %%
data3 = data3[['학교명','시군구','환경지표_score','위해지표_score','경감지표_score','total_score','종합_위험도']]
data3['종합_위험도'].value_counts()
# Out:
# 보통      68
# 위험      64
# 매우안전    64
# 매우위험    64
# 안전      60
# Name: 종합_위험도, dtype: int64

# %%
data3.dtypes
# Out:
# 학교명             object
# 시군구             object
# 환경지표_score     float64
# 위해지표_score       int64
# 경감지표_score       int64
# total_score    float64
# 종합_위험도          object
# dtype: object

# %%
# 저장 후 주석처리 
data3.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_종합지표.csv")

# %%
data_region = data3[['시군구','환경지표_score']]
data_region
# Out:
#       시군구  환경지표_score
# 0     송파구   48.715229
# 1    서대문구   46.193799
# 2     강동구   55.148267
# 3     양천구   65.103834
# 4     강서구   77.831186
# ..    ...         ...
# 315   도봉구   89.946627
# 316  동대문구   58.574818
# 317  동대문구   58.574818
# 318   강남구   19.071217
# 319  동대문구   58.574818
#
# [320 rows x 2 columns]

# %%
# 저장 후 주석처리 
data_region.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_종합지표_region.csv")

# %%
data3.columns
# Out:
# Index(['학교명', '시군구', '환경지표_score', '위해지표_score', '경감지표_score', 'total_score',
#        '종합_위험도'],
#       dtype='object')

# %%
data_school = data3[['학교명','위해지표_score','경감지표_score','total_score','종합_위험도']]
data_school
# Out:
#           학교명  위해지표_score  경감지표_score  total_score 종합_위험도
# 0      가락고등학교          20          20    46.644883     안전
# 1     가재울고등학교         100          20    69.267431     위험
# 2      강동고등학교          60          20    61.951835     위험
# 3      강서고등학교         100         100    53.821642     보통
# 4    강서공업고등학교          40          40    61.432352     보통
# ..        ...         ...         ...          ...    ...
# 315    효문고등학교          40          20    74.041027   매우위험
# 316  휘경공업고등학교          40          40    51.431740     안전
# 317  휘경여자고등학교         100          40    69.380762     위험
# 318    휘문고등학교          40          60    24.599284   매우안전
# 319    휘봉고등학교           0          40    39.465725   매우안전
#
# [320 rows x 5 columns]

# %%
# 저장 후 주석처리 
data_school.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_종합지표_school.csv")

# %% [markdown]
# # 종합지표(feauters)

# %%
data = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\DB_서울특별시_고등학교_정보.csv",index_col=0)
data = data[['학교명','시군구']]
data
# Out:
#           학교명   시군구
# 0      가락고등학교   송파구
# 1     가재울고등학교  서대문구
# 2      강동고등학교   강동구
# 3      강서고등학교   양천구
# 4    강서공업고등학교   강서구
# ..        ...   ...
# 315    효문고등학교   도봉구
# 316  휘경공업고등학교  동대문구
# 317  휘경여자고등학교  동대문구
# 318    휘문고등학교   강남구
# 319    휘봉고등학교  동대문구
#
# [320 rows x 2 columns]

# %%
data1 = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\DB_서울특별시_고등학교_학교폭력_환경지표_region_features.csv",index_col=0)
data1
# Out:
#      시군구  한부모가족지원법수급자_재가보호_가구원수  국민기초생활보장법수급자_가구원수  소득인식수준_중간소득  소득인식수준_고소득  \
# 0    강남구               6.136110          30.717739         44.9        34.7
# 1    강동구              14.148759          48.663157         52.6        19.8
# 2    강북구              30.076381         100.640197         52.9        23.4
# 3    강서구              20.076996          67.130300         62.7        17.2
# 4    관악구              13.034364          52.357698         58.0        20.0
# 5    광진구              16.504692          57.369402         53.1        23.0
# 6    구로구              15.837099          51.975126         51.1        26.5
# 7    금천구              25.154048          76.483007         61.0        18.2
# 8    노원구              15.516190          82.960155         45.7        18.5
# 9    도봉구              27.773168          85.260808         56.2        29.7
# 10  동대문구              17.442884          53.493406         46.3        22.0
# ...

# %%
data2 = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\DB_서울특별시_고등학교_학교폭력_위해지표_harm_features.csv",index_col=0)
data2
# Out:
#           학교명       교실안  신체폭력     집단따돌림  쉬는시간  500m_inner_Harmful_dept  \
# 0      가락고등학교  1.000000   0.0  1.000000   0.0                        0
# 1     가재울고등학교  0.000000   0.0  0.000000   0.0                        0
# 2      강동고등학교  0.000000   0.0  1.000000   1.0                        0
# 3      강서고등학교  0.000000   0.0  0.000000   0.0                        0
# 4    강서공업고등학교  0.666667   0.0  0.333333   1.0                        1
# ..        ...       ...   ...       ...   ...                      ...
# 315    효문고등학교  0.000000   0.0  0.000000   1.0                        0
# 316  휘경공업고등학교  1.000000   0.0  0.000000   0.0                        0
# 317  휘경여자고등학교  0.000000   0.0  0.000000   0.0                        1
# 318    휘문고등학교  1.000000   0.0  0.000000   0.0                        0
# 319    휘봉고등학교  0.500000   0.5  0.500000   0.5                        0
#
#      위해지표_score  위해지표_cluster 위해지표_학교폭력위험도
# 0            20             5           안전
# ...

# %%
data3 = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\DB_서울특별시_고등학교_학교폭력_경감지표_alleviate_features.csv",index_col=0)
data3
# Out:
#           학교명  평균 교육 시간(1학급당)  500m_inner_police_dept  500m_inner_cctv  \
# 0      가락고등학교          147.75                       0              102
# 1     가재울고등학교          100.00                       0              137
# 2      강동고등학교           30.65                       0               51
# 3      강서고등학교          237.30                       1              299
# 4    강서공업고등학교          187.50                       1               98
# ..        ...             ...                     ...              ...
# 315    효문고등학교          263.60                       0              109
# 316  휘경공업고등학교          187.90                       1               99
# 317  휘경여자고등학교           44.80                       1              136
# 318    휘문고등학교            4.60                       0              191
# 319    휘봉고등학교            6.30                       1               89
#
#      경감지표_score  경감지표_cluster 경감지표_학교폭력위험도
# 0            20             0   매우 안전하지 않음
# ...

# %%
data4 = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\DB_서울특별시_고등학교_학교폭력_종합지표.csv",index_col=0)
data4 = data4[['학교명','total_score','종합_위험도']]
data4
# Out:
#           학교명  total_score 종합_위험도
# 0      가락고등학교    46.644883     안전
# 1     가재울고등학교    69.267431     위험
# 2      강동고등학교    61.951835     위험
# 3      강서고등학교    53.821642     보통
# 4    강서공업고등학교    61.432352     보통
# ..        ...          ...    ...
# 315    효문고등학교    74.041027   매우위험
# 316  휘경공업고등학교    51.431740     안전
# 317  휘경여자고등학교    69.380762     위험
# 318    휘문고등학교    24.599284   매우안전
# 319    휘봉고등학교    39.465725   매우안전
#
# [320 rows x 3 columns]

# %%
df1 = pd.merge(data, data1, on=['시군구'], how='outer', sort=True)
df2 = pd.merge(df1, data2, on=['학교명'], how='outer', sort=True)
df3 = pd.merge(df2, data3, on=['학교명'], how='outer', sort=True)
df4 = pd.merge(df3, data4, on=['학교명'], how='outer', sort=True)
df4.columns
# Out:
# Index(['학교명', '시군구', '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수',
#        '소득인식수준_중간소득', '소득인식수준_고소득', '성인게임장수', '사건종별가정폭력', '사건종별데이트폭력',
#        '월평균소득금액(백만)', '다문화가족', '환경지표_score', '환경지표_cluster', '환경지표_학교폭력위험도',
#        '교실안', '신체폭력', '집단따돌림', '쉬는시간', '500m_inner_Harmful_dept', '위해지표_score',
#        '위해지표_cluster', '위해지표_학교폭력위험도', '평균 교육 시간(1학급당)',
#        '500m_inner_police_dept', '500m_inner_cctv', '경감지표_score',
#        '경감지표_cluster', '경감지표_학교폭력위험도', 'total_score', '종합_위험도'],
#       dtype='object')

# %%
# 저장 후 주석처리 
# df4.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_종합지표_features.csv")
